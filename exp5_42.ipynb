# %% [markdown]
# #Name: Riddhi Manjrekar
# #Roll No: 42
# #Batch: 2
#
#
# #Expt.-5: Disease Prediction using Naive Bayes and Neural Network with Comparison of Classifiers

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

# %%
import pandas as pd
# Load real data
data = load_breast_cancer()

# convert pandas to data frames
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
x = data.data
y = data.target
print("Classes : " ,data.target_names)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# Classes :  ['malignant' 'benign']

# %%
df.shape
# Out:
# (569, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
lr=LogisticRegression(max_iter=5000)
lrr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
print("train_accuracy:",accuracy_score(y_train,lr.predict(x_train)))

print("test_accuracy:" ,accuracy_score(y_test,pred_lr))
# Out:
# train_accuracy: 0.9582417582417583
# test_accuracy: 0.956140350877193

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
print("train_accuracy:",accuracy_score(y_train,dt.predict(x_train)))

print("test_accuracy:" ,accuracy_score(y_test,pred_dt))
# Out:
# train_accuracy: 1.0
# test_accuracy: 0.9473684210526315

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
print("train_accuracy:",accuracy_score(y_train,knn.predict(x_train)))

print("test_accuracy:" ,accuracy_score(y_test,pred_knn))
# Out:
# train_accuracy: 0.9406593406593406
# test_accuracy: 0.956140350877193

# %%
nn=neural_network= MLPClassifier()
nn.fit(x_train,y_train)
pred_nn=nn.predict(x_test)
print("train_accuracy:",accuracy_score(y_train,nn.predict(x_train)))

print("test_accuracy:" ,accuracy_score(y_test,pred_nn))
# Out:
# train_accuracy: 0.9362637362637363
# test_accuracy: 0.9473684210526315

# %%
gs=neural_network= MLPClassifier()
gs.fit(x_train,y_train)
pred_gs=gs.predict(x_test)
print("train_accuracy:",accuracy_score(y_train,gs.predict(x_train)))

print("test_accuracy:" ,accuracy_score(y_test,pred_gs))
# Out:
# train_accuracy: 0.9406593406593406
# test_accuracy: 0.9649122807017544

# %%
#mlp
mlp=MLPClassifier()

# %%
#precision
precision_lr=precision_score(y_test,pred_lr)

# %%
precision_lr=precision_score(y_test,pred_lr)
recall_lr=recall_score(y_test,pred_lr)
f1_scored_lr=f1_score(y_test,pred_lr)
roc_auc_lr = roc_auc_score(y_test,pred_lr)
print("Precision:",precision_lr)
print("Recall:",recall_lr)
print("F1 Score:",f1_scored_lr)
print("roc_auc:",roc_auc_lr)
# Out:
# Precision: 0.9459459459459459
# Recall: 0.9859154929577465
# F1 Score: 0.9655172413793104
# roc_auc: 0.9464461185718965

# %%
precision_dt=precision_score(y_test,pred_dt)
recall_dt=recall_score(y_test,pred_dt)
f1_scored_dt=f1_score(y_test,pred_dt)
roc_auc_dt = roc_auc_score(y_test,pred_dt)
print("Precision:",precision_lr)
print("Recall:",recall_dt)
print("F1 Score:",f1_scored_dt)
print("roc_auc:",roc_auc_dt)
# Out:
# Precision: 0.9459459459459459
# Recall: 0.9577464788732394
# F1 Score: 0.9577464788732394
# roc_auc: 0.9439895185063871

# %%
precision_knn=precision_score(y_test,pred_knn)
recall_knn=recall_score(y_test,pred_knn)
f1_scored_knn=f1_score(y_test,pred_knn)
roc_auc_knn = roc_auc_score(y_test,pred_knn)
print("Precision:",precision_knn)
print("Recall:",recall_knn)
print("F1 Score:",f1_scored_knn)
print("roc_auc:",roc_auc_knn)
# Out:
# Precision: 0.9342105263157895
# Recall: 1.0
# F1 Score: 0.9659863945578231
# roc_auc: 0.9418604651162791

# %%
precision_nn=precision_score(y_test,pred_nn)
recall_nn=recall_score(y_test,pred_nn)
f1_scored_nn=f1_score(y_test,pred_nn)
roc_auc_nn = roc_auc_score(y_test,pred_nn)
print("Precision:",precision_nn)
print("Recall:",recall_nn)
print("F1 Score:",f1_scored_nn)
print("roc_auc:",roc_auc_nn)
# Out:
# Precision: 0.9333333333333333
# Recall: 0.9859154929577465
# F1 Score: 0.958904109589041
# roc_auc: 0.9348182115951523

# %%
precision_gs=precision_score(y_test,pred_gs)
recall_gs=recall_score(y_test,pred_gs)
f1_scored_gs=f1_score(y_test,pred_gs)
roc_auc_gs = roc_auc_score(y_test,pred_gs)
print("Precision:",precision_gs)
print("Recall:",recall_gs)
print("F1 Score:",f1_scored_gs)
print("roc_auc:",roc_auc_gs)
# Out:
# Precision: 0.958904109589041
# Recall: 0.9859154929577465
# F1 Score: 0.9722222222222222
# roc_auc: 0.9580740255486406

# %%
cm_lr=confusion_matrix(y_test,pred_lr)
print("\nlogistic regression confusion matrix:")
print(cm_lr)
TN1,FP1,FN1,TP1=cm_lr.ravel()
type1_lr=FP1/(FP1+TN1)
type2_lr=FN1/(FN1+TP1)
print("FP1(type-1):",FP1)
print("FN1(type-2):",FN1)
print("type-1 error rate in %:",type1_lr*100)
print("type-2 error rate in %:",type2_lr*100)
# Out:
# logistic regression confusion matrix:
# [[39  4]
#  [ 1 70]]
# FP1(type-1): 4
# FN1(type-2): 1
# type-1 error rate in %: 9.30232558139535
# type-2 error rate in %: 1.4084507042253522

# %%
cm_dt=confusion_matrix(y_test,pred_dt)
print("\nlogistic regression confusion matrix:")
print(cm_dt)
TN1,FP1,FN1,TP1=cm_dt.ravel()
type1_dt=FP1/(FP1+TN1)
type2_dt=FN1/(FN1+TP1)
print("FP1(type-1):",FP1)
print("FN1(type-2):",FN1)
print("type-1 error rate in %:",type1_dt*100)
print("type-2 error rate in %:",type2_dt*100)
# Out:
# logistic regression confusion matrix:
# [[40  3]
#  [ 3 68]]
# FP1(type-1): 3
# FN1(type-2): 3
# type-1 error rate in %: 6.976744186046512
# type-2 error rate in %: 4.225352112676056

# %%
cm_knn=confusion_matrix(y_test,pred_knn)
print("\nlogistic regression confusion matrix:")
print(cm_knn)
TN1,FP1,FN1,TP1=cm_knn.ravel()
type1_knn=FP1/(FP1+TN1)
type2_knn=FN1/(FN1+TP1)
print("FP1(type-1):",FP1)
print("FN1(type-2):",FN1)
print("type-1 error rate in %:",type1_knn*100)
print("type-2 error rate in %:",type2_knn*100)
# Out:
# logistic regression confusion matrix:
# [[38  5]
#  [ 0 71]]
# FP1(type-1): 5
# FN1(type-2): 0
# type-1 error rate in %: 11.627906976744185
# type-2 error rate in %: 0.0

# %%
cm_nn=confusion_matrix(y_test,pred_nn)
print("\nlogistic regression confusion matrix:")
print(cm_nn)
TN1,FP1,FN1,TP1=cm_nn.ravel()
type1_nn=FP1/(FP1+TN1)
type2_nn=FN1/(FN1+TP1)
print("FP1(type-1):",FP1)
print("FN1(type-2):",FN1)
print("type-1 error rate in %:",type1_nn*100)
print("type-2 error rate in %:",type2_nn*100)
# Out:
# logistic regression confusion matrix:
# [[38  5]
#  [ 1 70]]
# FP1(type-1): 5
# FN1(type-2): 1
# type-1 error rate in %: 11.627906976744185
# type-2 error rate in %: 1.4084507042253522

# %%
cm_gs=confusion_matrix(y_test,pred_gs)
print("\nlogistic regression confusion matrix:")
print(cm_gs)
TN1,FP1,FN1,TP1=cm_gs.ravel()
type1_gs=FP1/(FP1+TN1)
type2_gs=FN1/(FN1+TP1)
print("FP1(type-1):",FP1)
print("FN1(type-2):",FN1)
print("type-1 error rate in %:",type1_gs*100)
print("type-2 error rate in %:",type2_gs*100)
# Out:
# logistic regression confusion matrix:
# [[40  3]
#  [ 1 70]]
# FP1(type-1): 3
# FN1(type-2): 1
# type-1 error rate in %: 6.976744186046512
# type-2 error rate in %: 1.4084507042253522
